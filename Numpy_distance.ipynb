# %%
import numpy as np
l1=[10,20,30,40,50,60,70,80]
arr1=np.array(l1)
arr1
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80])

# %%
a=10
b=20
c=30
d=a+b+c

# %%
np.mean(arr1)
# Out:
# 45.0

# %%
np.sum(arr1)/len(arr1)
# Out:
# 45.0

# %%
np.var(arr1)
# Out:
# 525.0

# %%
l1=[10,20,30,40,50,60,70,80]
mean=sum(l1)/len(l1)
s=0
for i in l1:
    val=((i-mean)**2)
    s=s+val
s/len(l1)
# Out:
# 525.0

# %%
#using Numpy only
l1=[10,20,30,40,50,60,70,80]
arr1=np.array(l1)
arr_mean=np.mean(arr1)
arr2=arr1-arr_mean
arr3=np.square(arr2)
arr4=np.sum(arr3)/len(l1)
arr4
# Out:
# 525.0

# %%
np.sum(np.square(arr1-arr_mean))/len(l1)
# Out:
# 525.0

# %%
np.sqrt(np.sum(np.square(arr1-arr_mean))/len(l1))
# Out:
# 22.9128784747792

# %%
#distance between two points
l1=[10,20]
l2=[30,40]
arr1=np.array(l1)
arr2=np.array(l2)
np.sqrt(np.sum(np.square(arr2-arr1)))
# Out:
# 28.284271247461902

# %%
# Out:
# 28.284271247461902

# %%
#Norm
#Cosine Similarity
<img src="https://images.shiksha.com/mediadata/ugcDocuments/images/wordpressImages/2022_12_euclidean-dis.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 735px; height: 265px; margin: 0px; width: 355px;" alt="How to Compute Euclidean Distance in Python - Shiksha Online" jsname="kn3ccd">
# Out:
#   Cell In[3], line 3
#     <img src="https://images.shiksha.com/mediadata/ugcDocuments/images/wordpressImages/2022_12_euclidean-dis.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 735px; height: 265px; margin: 0px; width: 355px;" alt="How to Compute Euclidean Distance in Python - Shiksha Online" jsname="kn3ccd">
#     ^
# SyntaxError: invalid syntax

# %%
#linear algebra
#Norm of X - 3**2, 4**2 -->root
from numpy.linalg import norm
x=[3,4]
norm(x)
#OR
arr1=np.array(x)
np.sqrt(np.sum(np.square(x)))
# Out:
# 5.0

# %%
#sqrt + 
#distance between two points
import numpy as np
l1=[10,20]
l2=[30,40]
arr1=np.array(l1)
arr2=np.array(l2)
np.sqrt(np.sum(np.square(arr1-arr2))) 
# OR
l1=[10,20]
l2=[30,40]
arr1=np.array(l1)
arr2=np.array(l2)
norm(arr1-arr2)
# Out:
# 28.284271247461902

# %%
import matplotlib.pyplot as plt
plt.arrow(0,0,1,2,color='blue',head_width=0.1)
plt.arrow(0,0,1,1,color='red',head_width=0.1)
plt.xlim(0,2)
plt.ylim(0,3)
plt.show()

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.6'

# %%
#COSINE Formula = A*B/ !!A!! ||B||
x=[10,20]
y=[20,40]
arr1=np.array(x)
arr2=np.array(y)
#Nr=np.dot(arr1,arr2)
#Dr=norm(arr1)*norm(arr2)
#Nr/Dr
Nr=np.dot(arr1,arr2)
Dr=norm(arr1)*norm(arr2)
Nr/Dr
# Out:
# 0.9999999999999999

# %%
import math
#math.cos(x)
#math.acos(Nr/Dr)
math.degrees(math.acos(0.99))
#Ans is in Radian. convert to Degree
# Out:
# 8.109614455994183

# %%
import math
math.degrees(math.acos(0))
# Out:
# 90.0

# %%
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
# !pip install -U sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.8/739.8 kB 3.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.8/795.8 kB 4.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 9.6 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 11.0 MB/s  0:00:01eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 9.2 MB/s  0:00:00m275.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.0/802.0 kB 3.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.6/554.6 MB ?  0:00:56/s eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.1/553.1 MB ?  0:00:54/s eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 11.7 MB/s  0:00:14ta 0:00:010:00:01
# ...

# %%
from sentence-transformers import SentenceTransformer
model=SentenceTransformer('all-MiniLM-L6-V2')
# Out:
#   Cell In[5], line 1
#     from sentence-transformers import SentenceTransformer
#                  ^
# SyntaxError: invalid syntax

# %%
# !pip install -U sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
#   Using cached sentence_transformers-6.0.1-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached transformers-5.16.1-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached tokenizers-0.23.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# ...
#   Using cached huggingface_hub-1.29.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached torch-2.14.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (37 kB)
# ...
#   Using cached click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached hf_xet-1.6.0-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# ...
#   Using cached regex-2026.9.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ...
#   Using cached safetensors-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# ...

# %%
sentences=['Modi is a PM of India','Virat is crickter','Messi is retired from football']
question=['Who is PM of India']

# %%
len(model.encode('King'))
# this model saves English data in Vector which has 384 values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 len(model.encode('King'))
#
# NameError: name 'model' is not defined

# %%
sen_vector=model.encode(sentences)

# %%
len(sen_vector)
qv=model.encode(question)

# %%
v1=sen_vector[0]
v2=sen_vector[1]
v3=sen_vector[2]
#apply cosine similarity
Nr=np.dot(qv,v1)
Dr=norm(qv)*norm(v1)
Nr/Dr

Nr=np.dot(qv,v2)
Dr=norm(qv)*norm(v2)
Nr/Dr

Nr=np.dot(qv,v3)
Dr=norm(qv)*norm(v3)
Nr/Dr
